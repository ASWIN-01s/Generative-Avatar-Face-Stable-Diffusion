# %% [markdown]
# <a href="https://colab.research.google.com/github/ASWIN-01s/generative-avatar-face/blob/main/aswin_Ai_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader
# Out:
# Tesla T4, 15109 MiB, 15109 MiB

# %% [markdown]
# https://github.com/ShivamShrirao/diffusers/tree/main/examples/dreambooth

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/examples/dreambooth/train_dreambooth.py
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/scripts/convert_diffusers_to_original_stable_diffusion.py
# %pip install -qq git+https://github.com/ShivamShrirao/diffusers
# %pip install -q -U --pre triton
# %pip install -q accelerate transformers ftfy bitsandbytes==0.35.0 gradio natsort safetensors xformers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 8.2 MB/s eta 0:00:00
#   Building wheel for diffusers (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 KB 17.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for lit (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.8/212.8 KB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 88.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 13.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 82.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 MB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 79.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 KB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 KB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 KB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 63.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 KB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 KB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 22.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 24.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 KB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 9.2 MB/s eta 0:00:00
#   Building wheel for ffmpy (setup.py) ... done

# %%
# https://huggingface.co/settings/tokens
# !mkdir -p ~/.huggingface
HUGGINGFACE_TOKEN = "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" 
# !echo -n "{HUGGINGFACE_TOKEN}" > ~/.huggingface/token

# %% [markdown]
# ## Settings and run

# %%
save_to_gdrive = True #@param {type:"boolean"}
if save_to_gdrive:
    from google.colab import drive
    drive.mount('/content/drive')


MODEL_NAME = "runwayml/stable-diffusion-v1-5" 



OUTPUT_DIR = "stable_diffusion_weights/aswin03" 
if save_to_gdrive:
    OUTPUT_DIR = "/content/drive/MyDrive/" + OUTPUT_DIR
else:
    OUTPUT_DIR = "/content/" + OUTPUT_DIR

print(f"[*] Weights will be saved at {OUTPUT_DIR}")

# !mkdir -p $OUTPUT_DIR
# Out:
# Mounted at /content/drive
# [*] Weights will be saved at /content/drive/MyDrive/stable_diffusion_weights/aswin03

# %% [markdown]
# # Start Training
#
# Use the table below to choose the best flags based on your memory and speed requirements. Tested on Tesla T4 GPU.
#
#
# | `fp16` | `train_batch_size` | `gradient_accumulation_steps` | `gradient_checkpointing` | `use_8bit_adam` | GB VRAM usage | Speed (it/s) |
# | ---- | ------------------ | ----------------------------- | ----------------------- | --------------- | ---------- | ------------ |
# | fp16 | 1                  | 1                             | TRUE                    | TRUE            | 9.92       | 0.93         |
# | no   | 1                  | 1                             | TRUE                    | TRUE            | 10.08      | 0.42         |
# | fp16 | 2                  | 1                             | TRUE                    | TRUE            | 10.4       | 0.66         |
# | fp16 | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 1.14         |
# | no   | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 0.49         |
# | fp16 | 1                  | 2                             | TRUE                    | TRUE            | 11.56      | 1            |
# | fp16 | 2                  | 1                             | FALSE                   | TRUE            | 13.67      | 0.82         |
# | fp16 | 1                  | 2                             | FALSE                   | TRUE            | 13.7       | 0.83          |
# | fp16 | 1                  | 1                             | TRUE                    | FALSE           | 15.79      | 0.77         |

# %% [markdown]
# Add `--gradient_checkpointing` flag for around 9.92 GB VRAM usage.
#
# remove `--use_8bit_adam` flag for full precision. Requires 15.79 GB with `--gradient_checkpointing` else 17.8 GB.
#
# remove `--train_text_encoder` flag to reduce memory usage further, degrades output quality.

# %%
# You can also add multiple concepts here. Try tweaking `--max_train_steps` accordingly.

concepts_list = [
    {
        "instance_prompt":      "photo of aswin03 person",
        "class_prompt":         "photo of a person",
        "instance_data_dir":    "/content/data/aswin03",
        "class_data_dir":       "/content/data/person"
    },
#     {
#         "instance_prompt":      "photo of ukj person",
#         "class_prompt":         "photo of a person",
#         "instance_data_dir":    "/content/data/ukj",
#         "class_data_dir":       "/content/data/person"
#     }
]

# `class_data_dir` contains regularization images
import json
import os
for c in concepts_list:
    os.makedirs(c["instance_data_dir"], exist_ok=True)

with open("concepts_list.json", "w") as f:
    json.dump(concepts_list, f, indent=4)

# %%
import os
from google.colab import files
import shutil

for c in concepts_list:
    print(f"Uploading instance images for `{c['instance_prompt']}`")
    uploaded = files.upload()
    for filename in uploaded.keys():
        dst_path = os.path.join(c['instance_data_dir'], filename)
        shutil.move(filename, dst_path)

# %%
# !accelerate launch train_dreambooth.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --pretrained_vae_name_or_path="stabilityai/sd-vae-ft-mse" \
  --output_dir=$OUTPUT_DIR \
  --revision="fp16" \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --seed=1337 \
  --resolution=512 \
  --train_batch_size=1 \
  --train_text_encoder \
  --mixed_precision="fp16" \
  --use_8bit_adam \
  --gradient_accumulation_steps=1 \
  --learning_rate=1e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --num_class_images=12 \
  --sample_batch_size=4 \
  --max_train_steps=1000 \
  --save_interval=1000 \
  --save_sample_prompt="photo of aswin03 person" \
  --concepts_list="concepts_list.json"

# Reduce the `--save_interval` to lower than `--max_train_steps` to save weights from intermediate steps.
# `--save_sample_prompt` can be same as `--instance_prompt` to generate intermediate samples (saved along with weights in samples directory).
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2023-03-17 09:49:22.430067: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-17 09:49:23.371061: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-17 09:49:23.371182: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-03-17 09:49:23.371202: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /usr/local/lib/python3.9/dist-packages/accelerate/accelerator.py:243: FutureWarning: `logging_dir` is deprecated and will be removed in version 0.18.0 of 🤗 Accelerate. Use `project_dir` instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/huggingface_hub/utils/_hf_folder.py:92: UserWarning: A token has been found in `/root/.huggingface/token`. This is the old path where tokens were stored. The new location is `/root/.cache/huggingface/token` which is configurable using `HF_HOME` environment variable. Your token has been copied to this new location. You can now safely delete the old token file manually or use `huggingface-cli logout`.
#   warnings.warn(
# Downloading (…)ch_model.safetensors: 100% 335M/335M [00:01<00:00, 259MB/s]
# Downloading (…)lve/main/config.json: 100% 547/547 [00:00<00:00, 77.5kB/s]
# Downloading (…)p16/model_index.json: 100% 543/543 [00:00<00:00, 73.3kB/s]
# text_encoder/model.safetensors not found
# Fetching 15 files:   0% 0/15 [00:00<?, ?it/s]
# Downloading pytorch_model.bin:   0% 0.00/246M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   4% 10.5M/246M [00:00<00:02, 84.9MB/s]
#
# Downloading (…)_checker/config.json:   0% 0.00/4.70k [00:00<?, ?B/s]
#
#
# Downloading (…)_encoder/config.json:   0% 0.00/636 [00:00<?, ?B/s]
#
#
#
# Downloading (…)rocessor_config.json:   0% 0.00/342 [00:00<?, ?B/s]
#
#
#
#
# Downloading (…)cheduler_config.json:   0% 0.00/307 [00:00<?, ?B/s]
#
#
#
#
#
# Downloading (…)_checker/config.json: 100% 4.70k/4.70k [00:00<00:00, 96.4kB/s]
# Downloading (…)_encoder/config.json: 100% 636/636 [00:00<00:00, 13.9kB/s]
# Downloading (…)rocessor_config.json: 100% 342/342 [00:00<00:00, 8.40kB/s]
# Downloading (…)cheduler_config.json: 100% 307/307 [00:00<00:00, 7.22kB/s]
# Fetching 15 files:   7% 1/15 [00:00<00:09,  1.44it/s]
#
# Downloading (…)cial_tokens_map.json: 100% 472/472 [00:00<00:00, 9.71kB/s]
#
# Downloading pytorch_model.bin:  13% 31.5M/246M [00:00<00:02, 105MB/s]
#
#
# Downloading pytorch_model.bin:   0% 0.00/608M [00:00<?, ?B/s]
#
#
# Downloading pytorch_model.bin:   2% 10.5M/608M [00:00<00:06, 95.0MB/s]
# Downloading pytorch_model.bin:  21% 52.4M/246M [00:00<00:01, 121MB/s]
# Downloading pytorch_model.bin:  30% 73.4M/246M [00:00<00:01, 133MB/s]
#
#
# Downloading pytorch_model.bin:   5% 31.5M/608M [00:00<00:04, 116MB/s]
#
# Downloading (…)tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 1.23MB/s]
#
# Downloading pytorch_model.bin:  38% 94.4M/246M [00:00<00:01, 110MB/s]
#
#
# Downloading pytorch_model.bin:   9% 52.4M/608M [00:00<00:05, 99.5MB/s]
#
# Downloading (…)on_pytorch_model.bin:   0% 0.00/1.72G [00:00<?, ?B/s]
#
#
#
# Downloading (…)okenizer_config.json: 100% 822/822 [00:00<00:00, 209kB/s]
#
# Downloading pytorch_model.bin:  47% 115M/246M [00:00<00:01, 121MB/s]
#
# Downloading (…)on_pytorch_model.bin:   1% 10.5M/1.72G [00:00<00:19, 88.4MB/s]
#
#
#
# Downloading (…)tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
#
# Downloading pytorch_model.bin:  12% 73.4M/608M [00:00<00:05, 102MB/s]
#
#
#
#
# Downloading (…)cc2/unet/config.json: 100% 806/806 [00:00<00:00, 283kB/s]
#
#
#
#
#
# Downloading (…)9cc2/vae/config.json: 100% 609/609 [00:00<00:00, 151kB/s]
#
#
# Downloading (…)on_pytorch_model.bin:   1% 21.0M/1.72G [00:00<00:23, 72.5MB/s]
#
#
# Downloading pytorch_model.bin:  14% 83.9M/608M [00:00<00:05, 95.5MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:   0% 0.00/167M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:  55% 136M/246M [00:01<00:01, 103MB/s]
#
# Downloading (…)on_pytorch_model.bin:   2% 31.5M/1.72G [00:00<00:21, 79.8MB/s]
#
#
# Downloading pytorch_model.bin:  16% 94.4M/608M [00:01<00:05, 86.8MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:   6% 10.5M/167M [00:00<00:02, 74.1MB/s]
#
#
#
# Downloading (…)tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 2.87MB/s]
#
# Downloading (…)tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 2.79MB/s]
#
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  13% 21.0M/167M [00:00<00:01, 88.2MB/s]
#
#
# Downloading pytorch_model.bin:  17% 105M/608M [00:01<00:05, 88.4MB/s]
# Downloading pytorch_model.bin:  64% 157M/246M [00:01<00:01, 88.6MB/s]
#
# Downloading (…)on_pytorch_model.bin:   3% 52.4M/1.72G [00:00<00:21, 76.5MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  19% 31.5M/167M [00:00<00:01, 81.4MB/s]
#
#
# Downloading pytorch_model.bin:  19% 115M/608M [00:01<00:06, 76.6MB/s]
#
# Downloading (…)on_pytorch_model.bin:   4% 62.9M/1.72G [00:00<00:19, 84.1MB/s]
# Downloading pytorch_model.bin:  68% 168M/246M [00:01<00:00, 84.1MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  25% 41.9M/167M [00:00<00:01, 79.3MB/s]
#
#
# Downloading pytorch_model.bin:  21% 126M/608M [00:01<00:05, 82.7MB/s]
#
# Downloading (…)on_pytorch_model.bin:   4% 73.4M/1.72G [00:00<00:18, 87.8MB/s]
# Downloading pytorch_model.bin:  72% 178M/246M [00:01<00:00, 82.9MB/s]
#
#
# Downloading pytorch_model.bin:  22% 136M/608M [00:01<00:05, 80.6MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  31% 52.4M/167M [00:00<00:01, 70.7MB/s]
#
# Downloading (…)on_pytorch_model.bin:   5% 83.9M/1.72G [00:01<00:20, 79.5MB/s]
# Downloading pytorch_model.bin:  77% 189M/246M [00:01<00:00, 84.4MB/s]
#
#
# Downloading pytorch_model.bin:  24% 147M/608M [00:01<00:05, 86.2MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  38% 62.9M/167M [00:00<00:01, 78.8MB/s]
#
# Downloading (…)on_pytorch_model.bin:   6% 105M/1.72G [00:01<00:17, 93.9MB/s]
# Downloading pytorch_model.bin:  85% 210M/246M [00:02<00:00, 95.7MB/s]
#
#
# Downloading pytorch_model.bin:  28% 168M/608M [00:01<00:04, 99.4MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  50% 83.9M/167M [00:00<00:00, 93.7MB/s]
# Downloading pytorch_model.bin:  94% 231M/246M [00:02<00:00, 104MB/s]
#
# Downloading (…)on_pytorch_model.bin:   7% 126M/1.72G [00:01<00:15, 99.8MB/s]
#
#
# Downloading pytorch_model.bin:  31% 189M/608M [00:01<00:03, 109MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  63% 105M/167M [00:01<00:00, 98.9MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  69% 115M/167M [00:01<00:00, 90.4MB/s]
# Downloading pytorch_model.bin: 100% 246M/246M [00:02<00:00, 87.4MB/s]
#
#
# Downloading pytorch_model.bin:  34% 210M/608M [00:02<00:04, 98.9MB/s]
#
# Downloading pytorch_model.bin: 100% 246M/246M [00:02<00:00, 95.7MB/s]
#
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  75% 126M/167M [00:01<00:00, 86.6MB/s]
#
#
# Downloading pytorch_model.bin:  36% 220M/608M [00:02<00:04, 95.7MB/s]
#
# Downloading (…)on_pytorch_model.bin:   9% 157M/1.72G [00:01<00:17, 88.5MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  81% 136M/167M [00:01<00:00, 79.0MB/s]
#
#
# Downloading pytorch_model.bin:  38% 231M/608M [00:02<00:04, 85.8MB/s]
#
# Downloading (…)on_pytorch_model.bin:  10% 168M/1.72G [00:01<00:19, 81.2MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  88% 147M/167M [00:01<00:00, 78.9MB/s]
#
#
# Downloading pytorch_model.bin:  40% 241M/608M [00:02<00:04, 83.4MB/s]
#
# Downloading (…)on_pytorch_model.bin:  10% 178M/1.72G [00:02<00:20, 76.5MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin:  94% 157M/167M [00:01<00:00, 82.4MB/s]
#
#
# Downloading pytorch_model.bin:  41% 252M/608M [00:02<00:04, 84.9MB/s]
#
#
#
#
# Downloading (…)on_pytorch_model.bin: 100% 167M/167M [00:01<00:00, 84.3MB/s]
#
#
# Downloading pytorch_model.bin:  43% 262M/608M [00:02<00:04, 84.7MB/s]
#
# Downloading (…)on_pytorch_model.bin: 100% 167M/167M [00:02<00:00, 79.5MB/s]
#
#
#
# Downloading pytorch_model.bin:  45% 273M/608M [00:03<00:03, 86.3MB/s]
#
# Downloading (…)on_pytorch_model.bin:  12% 210M/1.72G [00:02<00:18, 81.7MB/s]
#
#
# Downloading pytorch_model.bin:  47% 283M/608M [00:03<00:03, 84.9MB/s]
#
# Downloading (…)on_pytorch_model.bin:  13% 220M/1.72G [00:02<00:18, 82.5MB/s]
#
#
# Downloading pytorch_model.bin:  48% 294M/608M [00:03<00:03, 87.9MB/s]
#
# Downloading (…)on_pytorch_model.bin:  13% 231M/1.72G [00:02<00:17, 84.5MB/s]
#
#
# Downloading pytorch_model.bin:  52% 315M/608M [00:03<00:03, 92.6MB/s]
#
# Downloading (…)on_pytorch_model.bin:  15% 252M/1.72G [00:02<00:16, 91.4MB/s]
#
#
# Downloading pytorch_model.bin:  55% 336M/608M [00:03<00:02, 97.1MB/s]
#
# Downloading (…)on_pytorch_model.bin:  16% 273M/1.72G [00:03<00:14, 98.6MB/s]
#
#
# Downloading pytorch_model.bin:  59% 357M/608M [00:03<00:02, 101MB/s]
#
# Downloading (…)on_pytorch_model.bin:  17% 294M/1.72G [00:03<00:13, 103MB/s]
#
# Downloading (…)on_pytorch_model.bin:  18% 304M/1.72G [00:03<00:13, 103MB/s]
#
#
# Downloading pytorch_model.bin:  62% 377M/608M [00:04<00:02, 105MB/s]
#
# Downloading (…)on_pytorch_model.bin:  19% 325M/1.72G [00:03<00:12, 108MB/s]
#
#
# Downloading pytorch_model.bin:  66% 398M/608M [00:04<00:01, 112MB/s]
#
# Downloading (…)on_pytorch_model.bin:  20% 346M/1.72G [00:03<00:12, 109MB/s]
#
#
# Downloading pytorch_model.bin:  69% 419M/608M [00:04<00:01, 114MB/s]
#
# Downloading (…)on_pytorch_model.bin:  21% 367M/1.72G [00:03<00:11, 118MB/s]
#
#
# Downloading pytorch_model.bin:  72% 440M/608M [00:04<00:01, 118MB/s]
#
# Downloading (…)on_pytorch_model.bin:  23% 388M/1.72G [00:04<00:11, 119MB/s]
#
#
# Downloading pytorch_model.bin:  76% 461M/608M [00:04<00:01, 122MB/s]
#
# Downloading (…)on_pytorch_model.bin:  24% 409M/1.72G [00:04<00:10, 124MB/s]
#
#
# Downloading pytorch_model.bin:  79% 482M/608M [00:04<00:01, 123MB/s]
#
# Downloading (…)on_pytorch_model.bin:  25% 430M/1.72G [00:04<00:10, 123MB/s]
#
#
# Downloading pytorch_model.bin:  83% 503M/608M [00:05<00:00, 123MB/s]
#
# Downloading (…)on_pytorch_model.bin:  26% 451M/1.72G [00:04<00:10, 125MB/s]
#
#
# Downloading pytorch_model.bin:  86% 524M/608M [00:05<00:00, 126MB/s]
#
# Downloading (…)on_pytorch_model.bin:  27% 472M/1.72G [00:04<00:10, 116MB/s]
#
#
# Downloading pytorch_model.bin:  90% 545M/608M [00:05<00:00, 123MB/s]
#
# Downloading (…)on_pytorch_model.bin:  29% 493M/1.72G [00:04<00:09, 124MB/s]
#
#
# Downloading pytorch_model.bin:  93% 566M/608M [00:05<00:00, 127MB/s]
#
# Downloading (…)on_pytorch_model.bin:  30% 514M/1.72G [00:05<00:10, 118MB/s]
#
#
# Downloading pytorch_model.bin:  97% 587M/608M [00:05<00:00, 117MB/s]
#
# Downloading (…)on_pytorch_model.bin:  31% 535M/1.72G [00:05<00:10, 117MB/s]
#
#
# Downloading pytorch_model.bin: 100% 608M/608M [00:05<00:00, 103MB/s]
# Fetching 15 files:  27% 4/15 [00:06<00:19,  1.74s/it]
#
# Downloading (…)on_pytorch_model.bin:  32% 556M/1.72G [00:05<00:09, 127MB/s]
#
# Downloading (…)on_pytorch_model.bin:  34% 577M/1.72G [00:05<00:08, 140MB/s]
#
# Downloading (…)on_pytorch_model.bin:  35% 598M/1.72G [00:05<00:07, 154MB/s]
#
# Downloading (…)on_pytorch_model.bin:  37% 629M/1.72G [00:05<00:06, 180MB/s]
#
# Downloading (…)on_pytorch_model.bin:  38% 661M/1.72G [00:05<00:05, 201MB/s]
#
# Downloading (…)on_pytorch_model.bin:  40% 692M/1.72G [00:06<00:04, 223MB/s]
#
# Downloading (…)on_pytorch_model.bin:  42% 724M/1.72G [00:06<00:04, 230MB/s]
#
# Downloading (…)on_pytorch_model.bin:  44% 755M/1.72G [00:06<00:03, 244MB/s]
#
# Downloading (…)on_pytorch_model.bin:  46% 786M/1.72G [00:06<00:03, 251MB/s]
#
# Downloading (…)on_pytorch_model.bin:  48% 818M/1.72G [00:06<00:03, 251MB/s]
#
# Downloading (…)on_pytorch_model.bin:  49% 849M/1.72G [00:06<00:03, 245MB/s]
#
# Downloading (…)on_pytorch_model.bin:  51% 881M/1.72G [00:06<00:03, 257MB/s]
#
# Downloading (…)on_pytorch_model.bin:  53% 912M/1.72G [00:06<00:03, 248MB/s]
#
# Downloading (…)on_pytorch_model.bin:  55% 944M/1.72G [00:07<00:03, 258MB/s]
#
# Downloading (…)on_pytorch_model.bin:  57% 975M/1.72G [00:07<00:03, 241MB/s]
#
# Downloading (…)on_pytorch_model.bin:  59% 1.01G/1.72G [00:07<00:02, 240MB/s]
#
# Downloading (…)on_pytorch_model.bin:  60% 1.04G/1.72G [00:07<00:02, 247MB/s]
#
# Downloading (…)on_pytorch_model.bin:  62% 1.07G/1.72G [00:07<00:02, 254MB/s]
#
# Downloading (…)on_pytorch_model.bin:  64% 1.10G/1.72G [00:07<00:02, 239MB/s]
#
# Downloading (…)on_pytorch_model.bin:  66% 1.13G/1.72G [00:09<00:09, 59.4MB/s]
#
# Downloading (…)on_pytorch_model.bin:  67% 1.15G/1.72G [00:09<00:08, 69.9MB/s]
#
# Downloading (…)on_pytorch_model.bin:  69% 1.18G/1.72G [00:09<00:05, 90.0MB/s]
#
# Downloading (…)on_pytorch_model.bin:  71% 1.22G/1.72G [00:09<00:04, 112MB/s]
#
# Downloading (…)on_pytorch_model.bin:  73% 1.25G/1.72G [00:09<00:03, 137MB/s]
#
# Downloading (…)on_pytorch_model.bin:  74% 1.28G/1.72G [00:09<00:02, 160MB/s]
#
# Downloading (…)on_pytorch_model.bin:  76% 1.31G/1.72G [00:09<00:02, 181MB/s]
#
# Downloading (…)on_pytorch_model.bin:  78% 1.34G/1.72G [00:10<00:02, 188MB/s]
#
# Downloading (…)on_pytorch_model.bin:  80% 1.37G/1.72G [00:10<00:01, 210MB/s]
#
# Downloading (…)on_pytorch_model.bin:  82% 1.41G/1.72G [00:10<00:01, 223MB/s]
#
# Downloading (…)on_pytorch_model.bin:  84% 1.44G/1.72G [00:10<00:01, 230MB/s]
#
# Downloading (…)on_pytorch_model.bin:  85% 1.47G/1.72G [00:10<00:01, 243MB/s]
#
# Downloading (…)on_pytorch_model.bin:  87% 1.50G/1.72G [00:10<00:00, 247MB/s]
#
# Downloading (…)on_pytorch_model.bin:  89% 1.53G/1.72G [00:10<00:00, 246MB/s]
#
# Downloading (…)on_pytorch_model.bin:  91% 1.56G/1.72G [00:10<00:00, 246MB/s]
#
# Downloading (…)on_pytorch_model.bin:  93% 1.59G/1.72G [00:11<00:00, 241MB/s]
#
# Downloading (…)on_pytorch_model.bin:  95% 1.63G/1.72G [00:11<00:00, 230MB/s]
#
# Downloading (…)on_pytorch_model.bin:  96% 1.66G/1.72G [00:11<00:00, 228MB/s]
#
# Downloading (…)on_pytorch_model.bin:  98% 1.69G/1.72G [00:11<00:00, 233MB/s]
#
# Downloading (…)on_pytorch_model.bin: 100% 1.72G/1.72G [00:11<00:00, 148MB/s]
# Fetching 15 files: 100% 15/15 [00:12<00:00,  1.16it/s]
# /usr/local/lib/python3.9/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# 03/17/2023 09:49:52 - INFO - __main__ - Number of class images to sample: 12.
# Generating class images: 100% 3/3 [00:58<00:00, 19.37s/it]
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/paths.py:105: UserWarning: /usr/lib64-nvidia did not contain libcudart.so as expected! Searching further paths...
#   warn(
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('--listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https'), PosixPath('//colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/gpu-t4-s-1za8n51jgw80k --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true')}
#   warn(
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   warn(
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//ipykernel.pylab.backend_inline'), PosixPath('module')}
#   warn(
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 118
# CUDA SETUP: Loading binary /usr/local/lib/python3.9/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so...
# /usr/local/lib/python3.9/dist-packages/diffusers/configuration_utils.py:195: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# Downloading (…)cheduler_config.json: 100% 308/308 [00:00<00:00, 105kB/s]
# Caching latents: 100% 12/12 [00:05<00:00,  2.13it/s]
# 03/17/2023 09:51:10 - INFO - __main__ - ***** Running training *****
# 03/17/2023 09:51:10 - INFO - __main__ -   Num examples = 12
# 03/17/2023 09:51:10 - INFO - __main__ -   Num batches each epoch = 12
# 03/17/2023 09:51:10 - INFO - __main__ -   Num Epochs = 84
# 03/17/2023 09:51:10 - INFO - __main__ -   Instantaneous batch size per device = 1
# 03/17/2023 09:51:10 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 03/17/2023 09:51:10 - INFO - __main__ -   Gradient Accumulation steps = 1
# 03/17/2023 09:51:10 - INFO - __main__ -   Total optimization steps = 1000
# Steps: 100% 1000/1000 [12:52<00:00,  1.31it/s, loss=0.279, lr=1e-6]text_encoder/model.safetensors not found
#
# Fetching 15 files: 100% 15/15 [00:00<00:00, 54050.31it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#
# Generating samples:   0% 0/4 [00:00<?, ?it/s]
# Generating samples:  25% 1/4 [00:07<00:22,  7.54s/it]
# Generating samples:  50% 2/4 [00:11<00:10,  5.48s/it]
# Generating samples:  75% 3/4 [00:15<00:04,  4.70s/it]
# Generating samples: 100% 4/4 [00:19<00:00,  4.80s/it]
# [*] Weights saved at /content/drive/MyDrive/stable_diffusion_weights/aswin03/1000
# Steps: 100% 1000/1000 [13:37<00:00,  1.22it/s, loss=0.279, lr=1e-6]

# %%
WEIGHTS_DIR = "" 
if WEIGHTS_DIR == "":
    from natsort import natsorted
    from glob import glob
    import os
    WEIGHTS_DIR = natsorted(glob(OUTPUT_DIR + os.sep + "*"))[-1]
print(f"[*] WEIGHTS_DIR={WEIGHTS_DIR}")
# Out:
# [*] WEIGHTS_DIR=/content/drive/MyDrive/stable_diffusion_weights/aswin03/1000

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

weights_folder = OUTPUT_DIR
folders = sorted([f for f in os.listdir(weights_folder) if f != "0"], key=lambda x: int(x))

row = len(folders)
col = len(os.listdir(os.path.join(weights_folder, folders[0], "samples")))
scale = 4
fig, axes = plt.subplots(row, col, figsize=(col*scale, row*scale), gridspec_kw={'hspace': 0, 'wspace': 0})

for i, folder in enumerate(folders):
    folder_path = os.path.join(weights_folder, folder)
    image_folder = os.path.join(folder_path, "samples")
    images = [f for f in os.listdir(image_folder)]
    for j, image in enumerate(images):
        if row == 1:
            currAxes = axes[j]
        else:
            currAxes = axes[i, j]
        if i == 0:
            currAxes.set_title(f"Image {j}")
        if j == 0:
            currAxes.text(-0.1, 0.5, folder, rotation=0, va='center', ha='center', transform=currAxes.transAxes)
        image_path = os.path.join(image_folder, image)
        img = mpimg.imread(image_path)
        currAxes.imshow(img, cmap='gray')
        currAxes.axis('off')
        
plt.tight_layout()
plt.savefig('grid.png', dpi=72)

# %% [markdown]
# ## Convert weights to ckpt to use in web UIs like AUTOMATIC1111.

# %%
ckpt_path = WEIGHTS_DIR + "/model.ckpt"

half_arg = ""

fp16 = True #
if fp16:
    half_arg = "--half"
# !python convert_diffusers_to_original_stable_diffusion.py --model_path $WEIGHTS_DIR  --checkpoint_path $ckpt_path $half_arg
print(f"[*] Converted ckpt saved at {ckpt_path}")
# Out:
# Reshaping encoder.mid.attn_1.q.weight for SD format
# Reshaping encoder.mid.attn_1.k.weight for SD format
# Reshaping encoder.mid.attn_1.v.weight for SD format
# Reshaping encoder.mid.attn_1.proj_out.weight for SD format
# Reshaping decoder.mid.attn_1.q.weight for SD format
# Reshaping decoder.mid.attn_1.k.weight for SD format
# Reshaping decoder.mid.attn_1.v.weight for SD format
# Reshaping decoder.mid.attn_1.proj_out.weight for SD format
# [*] Converted ckpt saved at /content/drive/MyDrive/stable_diffusion_weights/aswin03/1000/model.ckpt

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline, DDIMScheduler
from IPython.display import display

model_path = WEIGHTS_DIR             # If you want to use previously trained model saved in gdrive, replace this with the full path of model in gdrive

pipe = StableDiffusionPipeline.from_pretrained(model_path, safety_checker=None, torch_dtype=torch.float16).to("cuda")
pipe.scheduler = DDIMScheduler.from_config(pipe.scheduler.config)
pipe.enable_xformers_memory_efficient_attention()
g_cuda = None
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .

# %%
g_cuda = torch.Generator(device='cuda')
seed = 434678 #@param {type:"number"}
g_cuda.manual_seed(seed)

# %%
#@title Run for generating images.

prompt = "A game art portrait of aswin03 person male wizard of the water element by cory loftis, hyperrealism, very detailed, vray, rembrandt lighting, artstation, deviantart, fantasy art, rpg portrait" #@param {type:"string"}
negative_prompt = "" #@param {type:"string"}
num_samples = 6 #@param {type:"number"}
guidance_scale = 7 #@param {type:"number"}
num_inference_steps = 24 #@param {type:"number"}
height = 512 #@param {type:"number"}
width = 512 #@param {type:"number"}

with autocast("cuda"), torch.inference_mode():
    images = pipe(
        prompt,
        height=height,
        width=width,
        negative_prompt=negative_prompt,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=g_cuda
    ).images

for img in images:
    display(img)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F527445C1C0>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F527445C580>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F527445C5E0>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F527445C520>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F527445C7F0>
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F527445C790>

# %%
#@markdown Run Gradio UI for generating images.
import gradio as gr

def inference(prompt, negative_prompt, num_samples, height=512, width=512, num_inference_steps=50, guidance_scale=7.5):
    with torch.autocast("cuda"), torch.inference_mode():
        return pipe(
                prompt, height=int(height), width=int(width),
                negative_prompt=negative_prompt,
                num_images_per_prompt=int(num_samples),
                num_inference_steps=int(num_inference_steps), guidance_scale=guidance_scale,
                generator=g_cuda
            ).images

with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column():
            prompt = gr.Textbox(label="Prompt", value="photo of zwx dog in a bucket")
            negative_prompt = gr.Textbox(label="Negative Prompt", value="")
            run = gr.Button(value="Generate")
            with gr.Row():
                num_samples = gr.Number(label="Number of Samples", value=4)
                guidance_scale = gr.Number(label="Guidance Scale", value=7.5)
            with gr.Row():
                height = gr.Number(label="Height", value=512)
                width = gr.Number(label="Width", value=512)
            num_inference_steps = gr.Slider(label="Steps", value=24)
        with gr.Column():
            gallery = gr.Gallery()

    run.click(inference, inputs=[prompt, negative_prompt, num_samples, height, width, num_inference_steps, guidance_scale], outputs=gallery)

demo.launch(debug=True)

# %%
#@title (Optional) Delete diffuser and old weights and only keep the ckpt to free up drive space.

#@markdown [ ! ] Caution, Only execute if you are sure u want to delete the diffuser format weights and only use the ckpt.
import shutil
from glob import glob
import os
for f in glob(OUTPUT_DIR+os.sep+"*"):
    if f != WEIGHTS_DIR:
        shutil.rmtree(f)
        print("Deleted", f)
for f in glob(WEIGHTS_DIR+"/*"):
    if not f.endswith(".ckpt") or not f.endswith(".json"):
        try:
            shutil.rmtree(f)
        except NotADirectoryError:
            continue
        print("Deleted", f)

# %%
#@title Free runtime memory
exit()
